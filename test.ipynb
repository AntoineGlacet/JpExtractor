# %%
import os
import openpyxl
from pptx import Presentation
from docx import Document

import spacy
from spacy.lang.ja.stop_words import STOP_WORDS
from collections import Counter

# %%
# need to run spacy download ja_core_news_sm (eg. with poetry run)
nlp = spacy.load("ja_core_news_sm")

# %%
def extract_text_from_excel(file_path):
    """Extracts text from an Excel file."""
    wb = openpyxl.load_workbook(file_path)
    text = ""

    for sheet in wb.worksheets:
        for row in sheet.iter_rows(values_only=True):
            text += " ".join(map(str, row)) + " "

    return text

def extract_text_from_powerpoint(file_path):
    """Extracts text from a PowerPoint file."""
    prs = Presentation(file_path)
    text = ""

    for slide in prs.slides:
        for shape in slide.shapes:
            if hasattr(shape, "text"):
                text += shape.text + " "

    return text

def extract_text_from_word(file_path):
    """Extracts text from a Word file."""
    doc = Document(file_path)
    text = ""

    for paragraph in doc.paragraphs:
        text += paragraph.text + " "

    return text

def process_directory(directory_path):
    """Processes all files in a directory and extracts Japanese words and their frequency."""
    japanese_words_frequency = {}

    for filename in os.listdir(directory_path):
        file_path = os.path.join(directory_path, filename)

        if filename.endswith(".xlsx"):
            text = extract_text_from_excel(file_path)
        elif filename.endswith(".pptx"):
            text = extract_text_from_powerpoint(file_path)
        elif filename.endswith(".docx"):
            text = extract_text_from_word(file_path)
        else:
            continue

        doc = nlp(text)

        for word in doc:
            japanese_words_frequency[word.lemma] = japanese_words_frequency.get(word.lemma, 0) + 1

    return japanese_words_frequency

# %%
test_text = "データは現代のビジネスにおいて非常に重要です。効果的なデータ処理とそのアーキテクチャは、企業の成功に不可欠です。特に、API（アプリケーションプログラミングインターフェース）とAnypointプラットフォームを活用することで、データの効率的な管理と統合が可能となります。まず第一に、APIは異なるシステムやアプリケーション間でデータを共有するための効果的な手段です。Anypointプラットフォームは、API管理と統合を容易にする先進的なツールを提供しており、異なるデータソースからの情報をシームレスに統合できます。データソリューションのアーキテクチャは、柔軟性と拡張性を備える必要があります。Anypointはこれらの要件に応えるために設計され、クラウドベースのアプローチを採用しています。これにより、データの迅速な処理と変更に対応することができ、ビジネスの要求に柔軟かつ効果的に対応できます。APIを使用したデータの統合は、リアルタイムでの情報共有を実現し、ビジネスプロセスの迅速な進化に対応します。Anypointプラットフォームの活用により、異なるデータフォーマットやプロトコルに対応することが容易になり、データの標準化と品質の向上が期待できます。セキュリティもまた、データソリューションにおいて不可欠です。APIとAnypointは堅牢なセキュリティメカニズムを提供し、データの機密性や整合性を確保します。これにより、機密情報の漏洩やデータの不正アクセスからビジネスを守ることができます。総じて、APIとAnypointを活用したデータソリューションのアーキテクチャは、ビジネスの競争力を向上させ、迅速な意思決定を可能にします。データの価値を最大限に引き出すためには、効果的なAPI管理と統合が不可欠であり、Anypointプラットフォームはその実現に貢献します。"

# %%
import ginza

# %%
nlp = spacy.load("ja_ginza")
doc = nlp(test_text)

# %%
# Tokenize, remove stopwords, and count word frequencies
word_freq_counter = Counter()
for token in doc:
    if token.text not in STOP_WORDS and token.is_alpha:
        word_freq_counter[token.lemma_] += 1

# Get a list of words sorted by frequency
sorted_words = [(word, freq) for word, freq in word_freq_counter.most_common()]

# Display the sorted list of words and their frequencies
for word, freq in sorted_words:
    print(f"Word: {word}, Frequency: {freq}")
# Out:
# Word: データ, Frequency: 14
# Word: API, Frequency: 7
# Word: anypoint, Frequency: 7
# Word: ビジネス, Frequency: 5
# Word: 統合, Frequency: 5
# Word: 効果的, Frequency: 4
# Word: プラットフォーム, Frequency: 4
# Word: 対応, Frequency: 4
# Word: アーキテクチャ, Frequency: 3
# Word: 不可欠, Frequency: 3
# Word: 活用, Frequency: 3
# Word: 管理, Frequency: 3
# Word: 異なる, Frequency: 3
# Word: ソリューション, Frequency: 3
# Word: 迅速, Frequency: 3
# Word: 処理, Frequency: 2
# Word: アプリケーション, Frequency: 2
# Word: 可能, Frequency: 2
# Word: 容易, Frequency: 2
# Word: 提供, Frequency: 2
# Word: 実現, Frequency: 2
# Word: 向上, Frequency: 2
# Word: セキュリティ, Frequency: 2
# Word: 現代, Frequency: 1
# Word: 非常, Frequency: 1
# Word: 重要, Frequency: 1
# Word: 企業, Frequency: 1
# Word: 成功, Frequency: 1
# Word: 特に, Frequency: 1
# Word: プログラミング, Frequency: 1
# Word: インターフェース, Frequency: 1
# Word: 効率的, Frequency: 1
# Word: まず, Frequency: 1
# Word: 第, Frequency: 1
# Word: システム, Frequency: 1
# Word: 間, Frequency: 1
# Word: 共有, Frequency: 1
# Word: 手段, Frequency: 1
# Word: 先進的, Frequency: 1
# Word: ツール, Frequency: 1
# Word: データソース, Frequency: 1
# Word: 情報, Frequency: 1
# Word: シームレス, Frequency: 1
# Word: 柔軟性, Frequency: 1
# Word: 拡張性, Frequency: 1
# Word: 備える, Frequency: 1
# Word: 必要, Frequency: 1
# Word: 要件, Frequency: 1
# Word: 応える, Frequency: 1
# Word: 設計, Frequency: 1
# Word: クラウド, Frequency: 1
# Word: ベース, Frequency: 1
# Word: アプローチ, Frequency: 1
# Word: 採用, Frequency: 1
# Word: 変更, Frequency: 1
# Word: 要求, Frequency: 1
# Word: 柔軟, Frequency: 1
# Word: 使用, Frequency: 1
# Word: リアルタイム, Frequency: 1
# Word: 情報共有, Frequency: 1
# Word: プロセス, Frequency: 1
# Word: 進化, Frequency: 1
# Word: フォーマット, Frequency: 1
# Word: プロトコル, Frequency: 1
# Word: 標準化, Frequency: 1
# Word: 品質, Frequency: 1
# Word: 期待, Frequency: 1
# Word: 堅牢, Frequency: 1
# Word: メカニズム, Frequency: 1
# Word: 機密, Frequency: 1
# Word: 性, Frequency: 1
# Word: 整合性, Frequency: 1
# Word: 確保, Frequency: 1
# Word: 機密情報, Frequency: 1
# Word: 漏洩, Frequency: 1
# Word: 不正, Frequency: 1
# Word: アクセス, Frequency: 1
# Word: 守る, Frequency: 1
# Word: 総じて, Frequency: 1
# Word: 競争力, Frequency: 1
# Word: 意思決定, Frequency: 1
# Word: 価値, Frequency: 1
# Word: 最大限, Frequency: 1
# Word: 引き出す, Frequency: 1
# Word: 貢献, Frequency: 1

# %%
for sent in doc.sents:
    for token in sent:
        print(
            token.i,
            token.orth_,
            token.lemma_,
            token.norm_,
            token.morph.get("Reading"),
            token.pos_,
            token.morph.get("Inflection"),
            token.tag_,
            token.dep_,
            token.head.i,
        )
    print('EOS')
# Out:
# 0 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nsubj 10
# 1 は は は ['ハ'] ADP [] 助詞-係助詞 case 0
# 2 現代 現代 現代 ['ゲンダイ'] NOUN [] 名詞-普通名詞-副詞可能 nmod 4
# 3 の の の ['ノ'] ADP [] 助詞-格助詞 case 2
# 4 ビジネス ビジネス ビジネス ['ビジネス'] NOUN [] 名詞-普通名詞-一般 obl 10
# 5 に に に ['ニ'] ADP [] 助詞-格助詞 case 4
# 6 おい おく おく ['オイ'] VERB ['五段-カ行;連用形-イ音便'] 動詞-一般 fixed 5
# 7 て て て ['テ'] SCONJ [] 助詞-接続助詞 fixed 5
# 8 非常 非常 非常 ['ヒジョウ'] ADJ [] 形状詞-一般 advcl 10
# 9 に だ だ ['ニ'] AUX ['助動詞-ダ;連用形-ニ'] 助動詞 aux 8
# 10 重要 重要 重要 ['ジュウヨウ'] ADJ [] 形状詞-一般 ROOT 10
# 11 です です です ['デス'] AUX ['助動詞-デス;終止形-一般'] 助動詞 aux 10
# 12 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 10
# EOS
# 13 効果的 効果的 効果的 ['コウカテキ'] ADJ [] 名詞-普通名詞-形状詞可能 acl 16
# 14 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 cop 13
# 15 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 compound 16
# 16 処理 処理 処理 ['ショリ'] NOUN [] 名詞-普通名詞-サ変可能 nmod 19
# 17 と と と ['ト'] ADP [] 助詞-格助詞 case 16
# 18 その その 其の ['ソノ'] DET [] 連体詞 det 19
# 19 アーキテクチャ アーキテクチャ アーキテクチャー ['アーキテクチャ'] NOUN [] 名詞-普通名詞-一般 nsubj 26
# 20 は は は ['ハ'] ADP [] 助詞-係助詞 case 19
# 21 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 19
# 22 企業 企業 企業 ['キギョウ'] NOUN [] 名詞-普通名詞-一般 nmod 24
# 23 の の の ['ノ'] ADP [] 助詞-格助詞 case 22
# 24 成功 成功 成功 ['セイコウ'] NOUN [] 名詞-普通名詞-サ変可能 obl 26
# 25 に に に ['ニ'] ADP [] 助詞-格助詞 case 24
# 26 不可欠 不可欠 不可欠 ['フカケツ'] ADJ [] 形状詞-一般 ROOT 26
# 27 です です です ['デス'] AUX ['助動詞-デス;終止形-一般'] 助動詞 aux 26
# 28 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 26
# EOS
# 29 特に 特に 特に ['トクニ'] ADV [] 副詞 advmod 56
# 30 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 29
# 31 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 nmod 39
# 32 （ ( ( ['キゴウ'] PUNCT [] 補助記号-括弧開 punct 31
# 33 アプリケーション アプリケーション アプリケーション ['アプリケーション'] NOUN [] 名詞-普通名詞-一般 compound 31
# 34 プログラミング プログラミング プログラミング ['プログラミング'] NOUN [] 名詞-普通名詞-サ変可能 compound 31
# 35 インターフェース インターフェース インターフェース ['インターフェース'] NOUN [] 名詞-普通名詞-一般 compound 31
# 36 ） ) ) ['キゴウ'] PUNCT [] 補助記号-括弧閉 punct 31
# 37 と と と ['ト'] ADP [] 助詞-格助詞 case 31
# 38 Anypoint anypoint anypoint ['anypoint'] NOUN [] 名詞-普通名詞-一般 compound 39
# 39 プラットフォーム プラットフォーム プラットフォーム ['プラットフォーム'] NOUN [] 名詞-普通名詞-一般 obj 41
# 40 を を を ['ヲ'] ADP [] 助詞-格助詞 case 39
# 41 活用 活用 活用 ['カツヨウ'] VERB [] 名詞-普通名詞-サ変可能 acl 43
# 42 する する 為る ['スル'] AUX ['サ行変格;連体形-一般'] 動詞-非自立可能 aux 41
# 43 こと こと こと ['コト'] NOUN [] 名詞-普通名詞-一般 obl 56
# 44 で だ だ ['デ'] ADP ['助動詞-ダ;連用形-一般'] 助動詞 case 43
# 45 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 43
# 46 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 50
# 47 の の の ['ノ'] ADP [] 助詞-格助詞 case 46
# 48 効率的 効率的 効率的 ['コウリツテキ'] ADJ [] 名詞-普通名詞-形状詞可能 acl 50
# 49 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 cop 48
# 50 管理 管理 管理 ['カンリ'] NOUN [] 名詞-普通名詞-サ変可能 nmod 52
# 51 と と と ['ト'] ADP [] 助詞-格助詞 case 50
# 52 統合 統合 統合 ['トウゴウ'] NOUN [] 名詞-普通名詞-サ変可能 nsubj 54
# 53 が が が ['ガ'] ADP [] 助詞-格助詞 case 52
# 54 可能 可能 可能 ['カノウ'] ADJ [] 形状詞-一般 advcl 56
# 55 と と と ['ト'] ADP [] 助詞-格助詞 case 54
# 56 なり なる 成る ['ナリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-非自立可能 ROOT 56
# 57 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 56
# 58 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 56
# EOS
# 59 まず まず 先ず ['マズ'] ADV [] 副詞 advmod 61
# 60 第 第 第 ['ダイ'] NOUN [] 接頭辞 compound 61
# 61 一 一 1 ['イチ'] NUM [] 名詞-数詞 obl 80
# 62 に に に ['ニ'] ADP [] 助詞-格助詞 case 61
# 63 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 61
# 64 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 nsubj 66
# 65 は は は ['ハ'] ADP [] 助詞-係助詞 case 64
# 66 異なる 異なる 異なる ['コトナル'] VERB ['五段-ラ行;連体形-一般'] 動詞-一般 acl 67
# 67 システム システム システム ['システム'] NOUN [] 名詞-普通名詞-一般 nmod 70
# 68 や や や ['ヤ'] ADP [] 助詞-副助詞 case 67
# 69 アプリケーション アプリケーション アプリケーション ['アプリケーション'] NOUN [] 名詞-普通名詞-一般 compound 70
# 70 間 間 間 ['カン'] NOUN [] 接尾辞-名詞的-副詞可能 nmod 76
# 71 で で で ['デ'] ADP [] 助詞-格助詞 case 70
# 72 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 obj 76
# 73 を を を ['ヲ'] ADP [] 助詞-格助詞 case 72
# 74 共有 共有 共有 ['キョウユウ'] VERB [] 名詞-普通名詞-サ変可能 compound 76
# 75 する する 為る ['スル'] AUX ['サ行変格;連体形-一般'] 動詞-非自立可能 aux 76
# 76 ため ため 為 ['タメ'] NOUN [] 名詞-普通名詞-副詞可能 nmod 78
# 77 の の の ['ノ'] ADP [] 助詞-格助詞 fixed 76
# 78 効果的 効果的 効果的 ['コウカテキ'] ADJ [] 名詞-普通名詞-形状詞可能 acl 80
# 79 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 cop 78
# 80 手段 手段 手段 ['シュダン'] NOUN [] 名詞-普通名詞-一般 ROOT 80
# 81 です です です ['デス'] AUX ['助動詞-デス;終止形-一般'] 助動詞 cop 80
# 82 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 80
# EOS
# 83 Anypoint anypoint anypoint ['anypoint'] NOUN [] 名詞-普通名詞-一般 compound 84
# 84 プラットフォーム プラットフォーム プラットフォーム ['プラットフォーム'] NOUN [] 名詞-普通名詞-一般 nsubj 99
# 85 は は は ['ハ'] ADP [] 助詞-係助詞 case 84
# 86 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 84
# 87 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 compound 88
# 88 管理 管理 管理 ['カンリ'] NOUN [] 名詞-普通名詞-サ変可能 nmod 90
# 89 と と と ['ト'] ADP [] 助詞-格助詞 case 88
# 90 統合 統合 統合 ['トウゴウ'] NOUN [] 名詞-普通名詞-サ変可能 obj 94
# 91 を を を ['ヲ'] ADP [] 助詞-格助詞 case 90
# 92 容易 容易 容易 ['ヨウイ'] ADJ [] 形状詞-一般 advcl 94
# 93 に だ だ ['ニ'] AUX ['助動詞-ダ;連用形-ニ'] 助動詞 aux 92
# 94 する する 為る ['スル'] VERB ['サ行変格;連体形-一般'] 動詞-非自立可能 acl 97
# 95 先進的 先進的 先進的 ['センシンテキ'] ADJ [] 名詞-普通名詞-形状詞可能 acl 97
# 96 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 cop 95
# 97 ツール ツール ツール ['ツール'] NOUN [] 名詞-普通名詞-一般 obj 99
# 98 を を を ['ヲ'] ADP [] 助詞-格助詞 case 97
# 99 提供 提供 提供 ['テイキョウ'] VERB [] 名詞-普通名詞-サ変可能 advcl 112
# 100 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 99
# 101 て て て ['テ'] SCONJ [] 助詞-接続助詞 mark 99
# 102 おり おる おる ['オリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-非自立可能 fixed 101
# 103 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 99
# 104 異なる 異なる 異なる ['コトナル'] VERB ['五段-ラ行;連体形-一般'] 動詞-一般 acl 105
# 105 データソース データソース データソース ['データソース'] NOUN [] 名詞-普通名詞-一般 nmod 108
# 106 から から から ['カラ'] ADP [] 助詞-格助詞 case 105
# 107 の の の ['ノ'] ADP [] 助詞-格助詞 case 105
# 108 情報 情報 情報 ['ジョウホウ'] NOUN [] 名詞-普通名詞-一般 obj 112
# 109 を を を ['ヲ'] ADP [] 助詞-格助詞 case 108
# 110 シームレス シームレス シームレス ['シームレス'] NOUN [] 名詞-普通名詞-一般 obl 112
# 111 に に に ['ニ'] ADP [] 助詞-格助詞 case 110
# 112 統合 統合 統合 ['トウゴウ'] VERB [] 名詞-普通名詞-サ変可能 ROOT 112
# 113 でき できる 出来る ['デキ'] AUX ['上一段-カ行;連用形-一般'] 動詞-非自立可能 aux 112
# 114 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 112
# 115 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 112
# EOS
# 116 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 compound 117
# 117 ソリューション ソリューション ソリューション ['ソリューション'] NOUN [] 名詞-普通名詞-一般 nmod 119
# 118 の の の ['ノ'] ADP [] 助詞-格助詞 case 117
# 119 アーキテクチャ アーキテクチャ アーキテクチャー ['アーキテクチャ'] NOUN [] 名詞-普通名詞-一般 dislocated 129
# 120 は は は ['ハ'] ADP [] 助詞-係助詞 case 119
# 121 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 119
# 122 柔軟性 柔軟性 柔軟性 ['ジュウナンセイ'] NOUN [] 名詞-普通名詞-一般 nmod 124
# 123 と と と ['ト'] ADP [] 助詞-格助詞 case 122
# 124 拡張性 拡張性 拡張性 ['カクチョウセイ'] NOUN [] 名詞-普通名詞-一般 obj 126
# 125 を を を ['ヲ'] ADP [] 助詞-格助詞 case 124
# 126 備える 備える 備える ['ソナエル'] VERB ['下一段-ア行;連体形-一般'] 動詞-一般 acl 127
# 127 必要 必要 必要 ['ヒツヨウ'] NOUN [] 名詞-普通名詞-形状詞可能 nsubj 129
# 128 が が が ['ガ'] ADP [] 助詞-格助詞 case 127
# 129 あり ある 有る ['アリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-非自立可能 ROOT 129
# 130 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 129
# 131 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 129
# EOS
# 132 Anypoint anypoint anypoint ['anypoint'] NOUN [] 名詞-普通名詞-一般 nsubj 151
# 133 は は は ['ハ'] ADP [] 助詞-係助詞 case 132
# 134 これ これ 此れ ['コレ'] PRON [] 代名詞 nmod 135
# 135 ら ら 等 ['ラ'] NOUN [] 接尾辞-名詞的-一般 nmod 137
# 136 の の の ['ノ'] ADP [] 助詞-格助詞 case 135
# 137 要件 要件 要件 ['ヨウケン'] NOUN [] 名詞-普通名詞-一般 obl 139
# 138 に に に ['ニ'] ADP [] 助詞-格助詞 case 137
# 139 応える 応える 答える ['コタエル'] VERB ['下一段-ア行;連体形-一般'] 動詞-一般 advcl 142
# 140 ため ため 為 ['タメ'] SCONJ [] 名詞-普通名詞-副詞可能 mark 139
# 141 に に に ['ニ'] SCONJ [] 助詞-格助詞 fixed 140
# 142 設計 設計 設計 ['セッケイ'] VERB [] 名詞-普通名詞-サ変可能 advcl 151
# 143 さ する 為る ['サ'] AUX ['サ行変格;未然形-サ'] 動詞-非自立可能 aux 142
# 144 れ れる れる ['レ'] AUX ['助動詞-レル;連用形-一般'] 助動詞 aux 142
# 145 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 142
# 146 クラウド クラウド クラウド ['クラウド'] NOUN [] 名詞-普通名詞-一般 compound 147
# 147 ベース ベース ベース ['ベース'] NOUN [] 名詞-普通名詞-一般 nmod 149
# 148 の の の ['ノ'] ADP [] 助詞-格助詞 case 147
# 149 アプローチ アプローチ アプローチ ['アプローチ'] NOUN [] 名詞-普通名詞-サ変可能 obj 151
# 150 を を を ['ヲ'] ADP [] 助詞-格助詞 case 149
# 151 採用 採用 採用 ['サイヨウ'] VERB [] 名詞-普通名詞-サ変可能 ROOT 151
# 152 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 151
# 153 て て て ['テ'] SCONJ [] 助詞-接続助詞 mark 151
# 154 い いる 居る ['イ'] VERB ['上一段-ア行;連用形-一般'] 動詞-非自立可能 fixed 153
# 155 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 151
# 156 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 151
# EOS
# 157 これ これ 此れ ['コレ'] PRON [] 代名詞 obl 169
# 158 に に に ['ニ'] ADP [] 助詞-格助詞 case 157
# 159 より よる よる ['ヨリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-一般 fixed 158
# 160 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 157
# 161 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 165
# 162 の の の ['ノ'] ADP [] 助詞-格助詞 case 161
# 163 迅速 迅速 迅速 ['ジンソク'] ADJ [] 形状詞-一般 acl 165
# 164 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 aux 163
# 165 処理 処理 処理 ['ショリ'] NOUN [] 名詞-普通名詞-サ変可能 nmod 167
# 166 と と と ['ト'] ADP [] 助詞-格助詞 case 165
# 167 変更 変更 変更 ['ヘンコウ'] NOUN [] 名詞-普通名詞-サ変可能 obl 169
# 168 に に に ['ニ'] ADP [] 助詞-格助詞 case 167
# 169 対応 対応 対応 ['タイオウ'] VERB [] 名詞-普通名詞-サ変可能 advcl 183
# 170 する する 為る ['スル'] AUX ['サ行変格;連体形-一般'] 動詞-非自立可能 aux 169
# 171 こと こと こと ['コト'] NOUN [] 名詞-普通名詞-一般 compound 169
# 172 が が が ['ガ'] ADP [] 助詞-格助詞 fixed 171
# 173 でき できる 出来る ['デキ'] AUX ['上一段-カ行;連用形-一般'] 動詞-非自立可能 fixed 171
# 174 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 169
# 175 ビジネス ビジネス ビジネス ['ビジネス'] NOUN [] 名詞-普通名詞-一般 nmod 177
# 176 の の の ['ノ'] ADP [] 助詞-格助詞 case 175
# 177 要求 要求 要求 ['ヨウキュウ'] NOUN [] 名詞-普通名詞-サ変可能 obl 183
# 178 に に に ['ニ'] ADP [] 助詞-格助詞 case 177
# 179 柔軟 柔軟 柔軟 ['ジュウナン'] ADJ [] 形状詞-一般 acl 181
# 180 かつ かつ 且つ ['カツ'] CCONJ [] 接続詞 cc 181
# 181 効果的 効果的 効果的 ['コウカテキ'] ADJ [] 名詞-普通名詞-形状詞可能 advcl 183
# 182 に だ だ ['ニ'] AUX ['助動詞-ダ;連用形-ニ'] 助動詞 cop 181
# 183 対応 対応 対応 ['タイオウ'] VERB [] 名詞-普通名詞-サ変可能 ROOT 183
# 184 でき できる 出来る ['デキ'] AUX ['上一段-カ行;連用形-一般'] 動詞-非自立可能 aux 183
# 185 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 183
# 186 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 183
# EOS
# 187 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 obj 189
# 188 を を を ['ヲ'] ADP [] 助詞-格助詞 case 187
# 189 使用 使用 使用 ['シヨウ'] VERB [] 名詞-普通名詞-サ変可能 acl 192
# 190 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 189
# 191 た た た ['タ'] AUX ['助動詞-タ;連体形-一般'] 助動詞 aux 189
# 192 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 194
# 193 の の の ['ノ'] ADP [] 助詞-格助詞 case 192
# 194 統合 統合 統合 ['トウゴウ'] NOUN [] 名詞-普通名詞-サ変可能 nsubj 202
# 195 は は は ['ハ'] ADP [] 助詞-係助詞 case 194
# 196 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 194
# 197 リアルタイム リアルタイム リアルタイム ['リアルタイム'] NOUN [] 名詞-普通名詞-一般 nmod 200
# 198 で で で ['デ'] ADP [] 助詞-格助詞 case 197
# 199 の の の ['ノ'] ADP [] 助詞-格助詞 case 197
# 200 情報共有 情報共有 情報共有 ['ジョウホウキョウユウ'] NOUN [] 名詞-普通名詞-サ変可能 obj 202
# 201 を を を ['ヲ'] ADP [] 助詞-格助詞 case 200
# 202 実現 実現 実現 ['ジツゲン'] VERB [] 名詞-普通名詞-サ変可能 advcl 212
# 203 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 202
# 204 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 202
# 205 ビジネス ビジネス ビジネス ['ビジネス'] NOUN [] 名詞-普通名詞-一般 compound 206
# 206 プロセス プロセス プロセス ['プロセス'] NOUN [] 名詞-普通名詞-一般 nmod 210
# 207 の の の ['ノ'] ADP [] 助詞-格助詞 case 206
# 208 迅速 迅速 迅速 ['ジンソク'] ADJ [] 形状詞-一般 acl 210
# 209 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 aux 208
# 210 進化 進化 進化 ['シンカ'] NOUN [] 名詞-普通名詞-サ変可能 obl 212
# 211 に に に ['ニ'] ADP [] 助詞-格助詞 case 210
# 212 対応 対応 対応 ['タイオウ'] VERB [] 名詞-普通名詞-サ変可能 ROOT 212
# 213 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 212
# 214 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 212
# 215 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 212
# EOS
# 216 Anypoint anypoint anypoint ['anypoint'] NOUN [] 名詞-普通名詞-一般 compound 217
# 217 プラットフォーム プラットフォーム プラットフォーム ['プラットフォーム'] NOUN [] 名詞-普通名詞-一般 nmod 219
# 218 の の の ['ノ'] ADP [] 助詞-格助詞 case 217
# 219 活用 活用 活用 ['カツヨウ'] NOUN [] 名詞-普通名詞-サ変可能 obl 229
# 220 に に に ['ニ'] ADP [] 助詞-格助詞 case 219
# 221 より よる よる ['ヨリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-一般 fixed 220
# 222 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 219
# 223 異なる 異なる 異なる ['コトナル'] VERB ['五段-ラ行;連体形-一般'] 動詞-一般 acl 225
# 224 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 compound 225
# 225 フォーマット フォーマット フォーマット ['フォーマット'] NOUN [] 名詞-普通名詞-サ変可能 nmod 227
# 226 や や や ['ヤ'] ADP [] 助詞-副助詞 case 225
# 227 プロトコル プロトコル プロトコル ['プロトコル'] NOUN [] 名詞-普通名詞-一般 obl 229
# 228 に に に ['ニ'] ADP [] 助詞-格助詞 case 227
# 229 対応 対応 対応 ['タイオウ'] VERB [] 名詞-普通名詞-サ変可能 acl 231
# 230 する する 為る ['スル'] AUX ['サ行変格;連体形-一般'] 動詞-非自立可能 aux 229
# 231 こと こと こと ['コト'] NOUN [] 名詞-普通名詞-一般 nsubj 235
# 232 が が が ['ガ'] ADP [] 助詞-格助詞 case 231
# 233 容易 容易 容易 ['ヨウイ'] ADJ [] 形状詞-一般 advcl 235
# 234 に だ だ ['ニ'] AUX ['助動詞-ダ;連用形-ニ'] 助動詞 aux 233
# 235 なり なる 成る ['ナリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-非自立可能 advcl 245
# 236 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 235
# 237 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 239
# 238 の の の ['ノ'] ADP [] 助詞-格助詞 case 237
# 239 標準化 標準化 標準化 ['ヒョウジュンカ'] NOUN [] 名詞-普通名詞-一般 nmod 241
# 240 と と と ['ト'] ADP [] 助詞-格助詞 case 239
# 241 品質 品質 品質 ['ヒンシツ'] NOUN [] 名詞-普通名詞-一般 nmod 243
# 242 の の の ['ノ'] ADP [] 助詞-格助詞 case 241
# 243 向上 向上 向上 ['コウジョウ'] NOUN [] 名詞-普通名詞-サ変可能 nsubj 245
# 244 が が が ['ガ'] ADP [] 助詞-格助詞 case 243
# 245 期待 期待 期待 ['キタイ'] VERB [] 名詞-普通名詞-サ変可能 ROOT 245
# 246 でき できる 出来る ['デキ'] AUX ['上一段-カ行;連用形-一般'] 動詞-非自立可能 aux 245
# 247 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 245
# 248 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 245
# EOS
# 249 セキュリティ セキュリティ セキュリティー ['セキュリティ'] NOUN [] 名詞-普通名詞-一般 nsubj 251
# 250 も も も ['モ'] ADP [] 助詞-係助詞 case 249
# 251 また また 又 ['マタ'] ADV [] 副詞 advmod 258
# 252 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 251
# 253 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 compound 254
# 254 ソリューション ソリューション ソリューション ['ソリューション'] NOUN [] 名詞-普通名詞-一般 obl 258
# 255 に に に ['ニ'] ADP [] 助詞-格助詞 case 254
# 256 おい おく おく ['オイ'] VERB ['五段-カ行;連用形-イ音便'] 動詞-一般 fixed 255
# 257 て て て ['テ'] SCONJ [] 助詞-接続助詞 fixed 255
# 258 不可欠 不可欠 不可欠 ['フカケツ'] ADJ [] 形状詞-一般 ROOT 258
# 259 です です です ['デス'] AUX ['助動詞-デス;終止形-一般'] 助動詞 aux 258
# 260 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 258
# EOS
# 261 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 nmod 263
# 262 と と と ['ト'] ADP [] 助詞-格助詞 case 261
# 263 Anypoint anypoint anypoint ['anypoint'] PROPN [] 名詞-固有名詞-一般 nsubj 280
# 264 は は は ['ハ'] ADP [] 助詞-係助詞 case 263
# 265 堅牢 堅牢 堅牢 ['ケンロウ'] ADJ [] 名詞-普通名詞-形状詞可能 acl 268
# 266 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 aux 265
# 267 セキュリティ セキュリティ セキュリティー ['セキュリティ'] NOUN [] 名詞-普通名詞-一般 compound 268
# 268 メカニズム メカニズム メカニズム ['メカニズム'] NOUN [] 名詞-普通名詞-一般 obj 270
# 269 を を を ['ヲ'] ADP [] 助詞-格助詞 case 268
# 270 提供 提供 提供 ['テイキョウ'] VERB [] 名詞-普通名詞-サ変可能 advcl 280
# 271 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 270
# 272 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 270
# 273 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 276
# 274 の の の ['ノ'] ADP [] 助詞-格助詞 case 273
# 275 機密 機密 機密 ['キミツ'] NOUN [] 名詞-普通名詞-一般 compound 276
# 276 性 性 性 ['セイ'] NOUN [] 接尾辞-名詞的-一般 nmod 278
# 277 や や や ['ヤ'] ADP [] 助詞-副助詞 case 276
# 278 整合性 整合性 整合性 ['セイゴウセイ'] NOUN [] 名詞-普通名詞-一般 obj 280
# 279 を を を ['ヲ'] ADP [] 助詞-格助詞 case 278
# 280 確保 確保 確保 ['カクホ'] VERB [] 名詞-普通名詞-サ変可能 ROOT 280
# 281 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 280
# 282 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 280
# 283 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 280
# EOS
# 284 これ これ 此れ ['コレ'] PRON [] 代名詞 obl 299
# 285 に に に ['ニ'] ADP [] 助詞-格助詞 case 284
# 286 より よる よる ['ヨリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-一般 fixed 285
# 287 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 284
# 288 機密情報 機密情報 機密情報 ['キミツジョウホウ'] NOUN [] 名詞-普通名詞-一般 nmod 290
# 289 の の の ['ノ'] ADP [] 助詞-格助詞 case 288
# 290 漏洩 漏洩 漏洩 ['ロウエイ'] NOUN [] 名詞-普通名詞-サ変可能 nmod 292
# 291 や や や ['ヤ'] ADP [] 助詞-副助詞 case 290
# 292 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 295
# 293 の の の ['ノ'] ADP [] 助詞-格助詞 case 292
# 294 不正 不正 不正 ['フセイ'] NOUN [] 名詞-普通名詞-形状詞可能 compound 295
# 295 アクセス アクセス アクセス ['アクセス'] NOUN [] 名詞-普通名詞-サ変可能 obl 299
# 296 から から から ['カラ'] ADP [] 助詞-格助詞 case 295
# 297 ビジネス ビジネス ビジネス ['ビジネス'] NOUN [] 名詞-普通名詞-一般 obj 299
# 298 を を を ['ヲ'] ADP [] 助詞-格助詞 case 297
# 299 守る 守る 守る ['マモル'] VERB ['五段-ラ行;連体形-一般'] 動詞-一般 ROOT 299
# 300 こと こと こと ['コト'] NOUN [] 名詞-普通名詞-一般 compound 299
# 301 が が が ['ガ'] ADP [] 助詞-格助詞 fixed 300
# 302 でき できる 出来る ['デキ'] AUX ['上一段-カ行;連用形-一般'] 動詞-非自立可能 fixed 300
# 303 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 299
# 304 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 299
# EOS
# 305 総じて 総じて 総じて ['ソウジテ'] ADV [] 副詞 advmod 334
# 306 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 305
# 307 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 nmod 309
# 308 と と と ['ト'] ADP [] 助詞-格助詞 case 307
# 309 Anypoint anypoint anypoint ['anypoint'] NOUN [] 名詞-普通名詞-一般 obj 311
# 310 を を を ['ヲ'] ADP [] 助詞-格助詞 case 309
# 311 活用 活用 活用 ['カツヨウ'] VERB [] 名詞-普通名詞-サ変可能 acl 315
# 312 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 311
# 313 た た た ['タ'] AUX ['助動詞-タ;連体形-一般'] 助動詞 aux 311
# 314 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 compound 315
# 315 ソリューション ソリューション ソリューション ['ソリューション'] NOUN [] 名詞-普通名詞-一般 nmod 317
# 316 の の の ['ノ'] ADP [] 助詞-格助詞 case 315
# 317 アーキテクチャ アーキテクチャ アーキテクチャー ['アーキテクチャ'] NOUN [] 名詞-普通名詞-一般 nsubj 334
# 318 は は は ['ハ'] ADP [] 助詞-係助詞 case 317
# 319 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 317
# 320 ビジネス ビジネス ビジネス ['ビジネス'] NOUN [] 名詞-普通名詞-一般 nmod 322
# 321 の の の ['ノ'] ADP [] 助詞-格助詞 case 320
# 322 競争力 競争力 競争力 ['キョウソウリョク'] NOUN [] 名詞-普通名詞-一般 obj 324
# 323 を を を ['ヲ'] ADP [] 助詞-格助詞 case 322
# 324 向上 向上 向上 ['コウジョウ'] VERB [] 名詞-普通名詞-サ変可能 advcl 334
# 325 さ する 為る ['サ'] AUX ['サ行変格;未然形-サ'] 動詞-非自立可能 aux 324
# 326 せ せる せる ['セ'] AUX ['下一段-サ行;連用形-一般'] 助動詞 aux 324
# 327 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 324
# 328 迅速 迅速 迅速 ['ジンソク'] ADJ [] 形状詞-一般 acl 330
# 329 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 aux 328
# 330 意思決定 意思決定 意思決定 ['イシケッテイ'] NOUN [] 名詞-普通名詞-一般 obj 334
# 331 を を を ['ヲ'] ADP [] 助詞-格助詞 case 330
# 332 可能 可能 可能 ['カノウ'] ADJ [] 形状詞-一般 advcl 334
# 333 に だ だ ['ニ'] AUX ['助動詞-ダ;連用形-ニ'] 助動詞 aux 332
# 334 し する 為る ['シ'] VERB ['サ行変格;連用形-一般'] 動詞-非自立可能 ROOT 334
# 335 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 334
# 336 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 334
# EOS
# 337 データ データ データ ['データ'] NOUN [] 名詞-普通名詞-一般 nmod 339
# 338 の の の ['ノ'] ADP [] 助詞-格助詞 case 337
# 339 価値 価値 価値 ['カチ'] NOUN [] 名詞-普通名詞-一般 obj 343
# 340 を を を ['ヲ'] ADP [] 助詞-格助詞 case 339
# 341 最大限 最大限 最大限 ['サイダイゲン'] NOUN [] 名詞-普通名詞-一般 obl 343
# 342 に に に ['ニ'] ADP [] 助詞-格助詞 case 341
# 343 引き出す 引き出す 引き出す ['ヒキダス'] VERB ['五段-サ行;連体形-一般'] 動詞-一般 advcl 355
# 344 ため ため 為 ['タメ'] SCONJ [] 名詞-普通名詞-副詞可能 mark 343
# 345 に に に ['ニ'] SCONJ [] 助詞-格助詞 fixed 344
# 346 は は は ['ハ'] ADP [] 助詞-係助詞 case 343
# 347 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 343
# 348 効果的 効果的 効果的 ['コウカテキ'] ADJ [] 名詞-普通名詞-形状詞可能 acl 351
# 349 な だ だ ['ナ'] AUX ['助動詞-ダ;連体形-一般'] 助動詞 cop 348
# 350 API API API ['エーピーアイ'] NOUN [] 名詞-普通名詞-一般 compound 351
# 351 管理 管理 管理 ['カンリ'] NOUN [] 名詞-普通名詞-サ変可能 nmod 353
# 352 と と と ['ト'] ADP [] 助詞-格助詞 case 351
# 353 統合 統合 統合 ['トウゴウ'] NOUN [] 名詞-普通名詞-サ変可能 nsubj 355
# 354 が が が ['ガ'] ADP [] 助詞-格助詞 case 353
# 355 不可欠 不可欠 不可欠 ['フカケツ'] ADJ [] 形状詞-一般 advcl 365
# 356 で だ だ ['デ'] AUX ['助動詞-ダ;連用形-一般'] 助動詞 aux 355
# 357 あり ある 有る ['アリ'] VERB ['五段-ラ行;連用形-一般'] 動詞-非自立可能 fixed 356
# 358 、 、 、 ['、'] PUNCT [] 補助記号-読点 punct 355
# 359 Anypoint anypoint anypoint ['anypoint'] PROPN [] 名詞-普通名詞-一般 compound 360
# 360 プラットフォーム プラットフォーム プラットフォーム ['プラットフォーム'] NOUN [] 名詞-普通名詞-一般 nsubj 365
# 361 は は は ['ハ'] ADP [] 助詞-係助詞 case 360
# 362 その その 其の ['ソノ'] DET [] 連体詞 det 363
# 363 実現 実現 実現 ['ジツゲン'] NOUN [] 名詞-普通名詞-サ変可能 obl 365
# 364 に に に ['ニ'] ADP [] 助詞-格助詞 case 363
# 365 貢献 貢献 貢献 ['コウケン'] VERB [] 名詞-普通名詞-サ変可能 ROOT 365
# 366 し する 為る ['シ'] AUX ['サ行変格;連用形-一般'] 動詞-非自立可能 aux 365
# 367 ます ます ます ['マス'] AUX ['助動詞-マス;終止形-一般'] 助動詞 aux 365
# 368 。 。 。 ['。'] PUNCT [] 補助記号-句点 punct 365
# EOS
